# %%
# %sql
use catalog samples;

show tables in nyctaxi;

# %%
# %sql
use catalog hive_metastore;
create database if not exists crm;

# %%
# %sql
create table if not exists crm.customers (id int, name string, email string, market string) cluster by (market);

# %%
# %sql
insert into crm.customers values (1, 'John Doe', 'john.doe@example.com', 'DE'), (2, 'Jane Smith', 'jane.smith@example.com', 'DE'), (3, 'Bob Johnson', 'bob.johnson@example.com', 'UK'), (4, 'Alice Williams', 'alice.williams@example.com', 'UK'), (5, 'Charlie Brown', 'charlie.brown@example.com', 'CN'), (6, 'David Lee', 'david.lee@example.com', 'CN' )

# %%
# %sql
describe detail crm.customers
